# %%
import pandas_datareader.data as web
import pandas as pd
import numpy as np

from pprint import pprint
from tqdm.auto import tqdm

# %%
def fetch_economic_data(indicators, start, end, api_key=None):
    economic_data = {}
    for indicator in tqdm(indicators):
        try:
            data = web.DataReader(indicator, "fred", start, end, api_key=api_key)
            economic_data[indicator] = data
        except Exception as e:
            print(f"Could not fetch data for {indicator}. Error: {e}")
    return economic_data

# %%
import pickle

with open("data/raw/economic_indicators.pkl", "rb") as f:
    economic_indicators_dict = pickle.load(f)

economic_indicators_dict
# Out:
# {'Gross Domestic Product': 'GDP',
#  'Consumer Price Index for All Urban Consumers': 'CPIAUCNS',
#  'Civilian Unemployment Rate': 'UNRATE',
#  'Effective Federal Funds Rate': 'FEDFUNDS',
#  'Trade Weighted U.S. Dollar Index': 'DTWEXM',
#  '10-Year Treasury Constant Maturity Minus 2-Year Treasury Constant Maturity': 'T10Y2Y',
#  'M2 Money Stock': 'M2',
#  'Personal Consumption Expenditures': 'PCE',
#  'Homeownership Rate in the U.S.': 'HOANBS',
#  'Total Business Inventories': 'BUSINV',
#  'Industrial Production Index': 'INDPRO',
#  'Real Personal Income Less Current Transfer Receipts': 'REALLN',
#  'Real Disposable Personal Income': 'W875RX1',
#  'Total Nonfarm Payrolls': 'PAYEMS',
#  'Personal Saving Rate': 'PSAVERT',
#  'Corporate Profits After Tax': 'A939RX0Q048SBEA',
#  'National Financial Conditions Index': 'NFCI',
#  'Velocity of M2 Money Stock': 'WM2NS',
#  'University of Michigan: Consumer Sentiment': 'UMCSENT',
#  'Crude Oil Prices': 'OILPRICE',
#  'High Yield Corporate Bond Yield': 'BAMLH0A0HYM2',
#  '10-Year Treasury Constant Maturity Rate': 'GS10',
#  'Corporate Profits': 'CP',
#  'St. Louis Fed Financial Stress Index': 'STLFSI',
#  'Leading Index for the United States': 'USSLIND',
#  'Real Gross Domestic Product': 'GDPC1',
#  'Return on Average Assets for all U.S. Banks': 'USROA'}

# %%
economic_indicators = [i for i in economic_indicators_dict.values()]
pprint(', '.join(economic_indicators))
# Out:
# ('GDP, CPIAUCNS, UNRATE, FEDFUNDS, DTWEXM, T10Y2Y, M2, PCE, HOANBS, BUSINV, '
#  'INDPRO, REALLN, W875RX1, PAYEMS, PSAVERT, A939RX0Q048SBEA, NFCI, WM2NS, '
#  'UMCSENT, OILPRICE, BAMLH0A0HYM2, GS10, CP, STLFSI, USSLIND, GDPC1, USROA')

# %%
api_key = "7241f282cb7ac930cf729ca9d1acb3af"
economic_data = fetch_economic_data(economic_indicators, "1990-01-01", "2023-09-07", api_key=api_key)
# Out:
#   0%|          | 0/27 [00:00<?, ?it/s]

# %%
freq = {k: pd.infer_freq(v.index) for k, v in economic_data.items()}
freq
# Out:
# {'GDP': 'QS-OCT',
#  'CPIAUCNS': 'MS',
#  'UNRATE': 'MS',
#  'FEDFUNDS': 'MS',
#  'DTWEXM': 'B',
#  'T10Y2Y': 'B',
#  'M2': 'W-MON',
#  'PCE': 'MS',
#  'HOANBS': 'QS-OCT',
#  'BUSINV': 'MS',
#  'INDPRO': 'MS',
#  'REALLN': 'MS',
#  'W875RX1': 'MS',
#  'PAYEMS': 'MS',
#  'PSAVERT': 'MS',
#  'A939RX0Q048SBEA': 'QS-OCT',
#  'NFCI': 'W-FRI',
#  'WM2NS': 'W-MON',
#  'UMCSENT': 'MS',
#  'OILPRICE': 'MS',
#  'BAMLH0A0HYM2': None,
#  'GS10': 'MS',
#  'CP': 'QS-OCT',
#  'STLFSI': 'W-FRI',
#  'USSLIND': 'MS',
#  'GDPC1': 'QS-OCT',
#  'USROA': 'QS-OCT'}

# %%
economic_data_resampled = {k: v.resample("B").last() for k, v in economic_data.items()}
freq_resampled = {k: pd.infer_freq(v.index) for k, v in economic_data_resampled.items()}
freq_resampled
# Out:
# {'GDP': 'B',
#  'CPIAUCNS': 'B',
#  'UNRATE': 'B',
#  'FEDFUNDS': 'B',
#  'DTWEXM': 'B',
#  'T10Y2Y': 'B',
#  'M2': 'B',
#  'PCE': 'B',
#  'HOANBS': 'B',
#  'BUSINV': 'B',
#  'INDPRO': 'B',
#  'REALLN': 'B',
#  'W875RX1': 'B',
#  'PAYEMS': 'B',
#  'PSAVERT': 'B',
#  'A939RX0Q048SBEA': 'B',
#  'NFCI': 'B',
#  'WM2NS': 'B',
#  'UMCSENT': 'B',
#  'OILPRICE': 'B',
#  'BAMLH0A0HYM2': 'B',
#  'GS10': 'B',
#  'CP': 'B',
#  'STLFSI': 'B',
#  'USSLIND': 'B',
#  'GDPC1': 'B',
#  'USROA': 'B'}

# %%
econ_df = pd.concat([v for v in economic_data_resampled.values()], axis=1)
econ_df_interpolated = econ_df.interpolate('akima').interpolate('linear')
# econ_df_interpolated.to_csv('data/raw/econ_data_with_nulls.csv')

# %%
econ_df_interpolated_no_nulls = econ_df_interpolated.dropna(axis=1)

# %%
econ_df_interpolated_no_nulls.head(3)
# Out:
#                     GDP    CPIAUCNS    UNRATE  FEDFUNDS           M2  \
# DATE
# 1990-01-01  5872.701000  127.400000  5.400000  8.230000  3161.100000
# 1990-01-02  5873.884000  127.416670  5.396936  8.229793  3161.699245
# 1990-01-03  5875.061336  127.433607  5.393852  8.229631  3162.250543
#
#                     PCE     HOANBS     INDPRO      REALLN      W875RX1  ...  \
# DATE                                                                    ...
# 1990-01-01  3730.700000  88.482000  61.644000  765.808900  6798.600000  ...
# 1990-01-02  3730.112311  88.477923  61.665975  766.118885  6799.630247  ...
# 1990-01-03  3729.545632  88.473838  61.687625  766.428515  6800.635500  ...
#
#              PSAVERT  A939RX0Q048SBEA        WM2NS    UMCSENT   OILPRICE  \
# DATE
# 1990-01-01  8.000000     37617.000000  3181.900000  93.000000  22.641000
# 1990-01-02  8.033922     37617.900197  3185.659726  92.799287  22.645280
# 1990-01-03  8.066905     37618.777405  3189.069155  92.600421  22.649263
#
#                 GS10          CP   USSLIND        GDPC1     USROA
# DATE
# 1990-01-01  8.210000  268.869000  1.710000  9364.259000  0.750000
# 1990-01-02  8.220386  269.066101  1.693781  9364.801212  0.749525
# 1990-01-03  8.230666  269.262463  1.678138  9365.338038  0.749048
#
# [3 rows x 21 columns]

# %%
import yfinance as yf

start = econ_df_interpolated_no_nulls.index.min()
end = econ_df_interpolated_no_nulls.index.max() + pd.DateOffset(days=1)

url = "https://en.wikipedia.org/wiki/List_of_S%26P_500_companies"

ticker_list = pd.read_html(url)[0]["Symbol"]
ticker_list = [i.replace('.', '-') for i in ticker_list]

stock_prices = yf.download(ticker_list, start, end)["Adj Close"]

stock_prices.head()
# Out:
# [*********************100%***********************]  503 of 503 completed
#              A  AAL      AAPL  ABBV       ABT  ACGL  ACN      ADBE       ADI  \
# Date
# 1990-01-02 NaN  NaN  0.263761   NaN  1.837212   NaN  NaN  1.188340  1.021221
# 1990-01-03 NaN  NaN  0.265531   NaN  1.843844   NaN  NaN  1.247023  0.968170
# 1990-01-04 NaN  NaN  0.266417   NaN  1.840529   NaN  NaN  1.305707  0.954908
# 1990-01-05 NaN  NaN  0.267302   NaN  1.820630   NaN  NaN  1.335048  0.954908
# 1990-01-08 NaN  NaN  0.269072   NaN  1.829963   NaN  NaN  1.352692  0.954908
#
#                  ADM  ...  WYNN       XEL       XOM      XRAY  XYL  YUM  ZBH  \
# Date                  ...
# 1990-01-02  4.656209  ...   NaN  4.213065  4.034966  0.855866  NaN  NaN  NaN
# 1990-01-03  4.656209  ...   NaN  4.200062  3.994619  0.855866  NaN  NaN  NaN
# 1990-01-04  4.630906  ...   NaN  4.096036  3.954268  0.821631  NaN  NaN  NaN
# 1990-01-05  4.428461  ...   NaN  4.057025  3.934095  0.872984  NaN  NaN  NaN
# 1990-01-08  4.479073  ...   NaN  4.018018  3.994619  0.838749  NaN  NaN  NaN
#
#             ZBRA      ZION  ZTS
# Date
# 1990-01-02   NaN  1.818956  NaN
# 1990-01-03   NaN  1.851438  NaN
# 1990-01-04   NaN  1.851438  NaN
# 1990-01-05   NaN  1.851438  NaN
# 1990-01-08   NaN  1.851438  NaN
#
# [5 rows x 503 columns]

# %%
stock_prices_no_nulls = stock_prices.dropna(axis=1)
stock_prices_no_nulls
# Out:
#                   AAPL         ABT        ADBE         ADI        ADM  \
# Date
# 1990-01-02    0.263761    1.837212    1.188340    1.021221   4.656209
# 1990-01-03    0.265531    1.843844    1.247023    0.968170   4.656209
# 1990-01-04    0.266417    1.840529    1.305707    0.954908   4.630906
# 1990-01-05    0.267302    1.820630    1.335048    0.954908   4.428461
# 1990-01-08    0.269072    1.829963    1.352692    0.954908   4.479073
# ...                ...         ...         ...         ...        ...
# 2023-08-31  187.869995  102.900002  559.340027  180.919998  79.300003
# 2023-09-01  189.460007  102.849998  563.210022  182.429993  79.790001
# 2023-09-05  189.699997  100.879997  564.880005  181.539993  78.879997
# 2023-09-06  182.910004  101.559998  561.940002  182.179993  77.459999
# 2023-09-07  177.559998  100.669998  560.460022  178.460007  78.529999
#
#                    ADP        ADSK        AEP        AFL         AIG  ...  \
# Date                                                                  ...
# 1990-01-02    2.720687    4.496894   5.993506   0.649151  106.041237  ...
# 1990-01-03    2.707051    4.608617   5.970888   0.635339  105.915619  ...
# 1990-01-04    2.693412    4.496894   5.880419   0.621527  104.407829  ...
# 1990-01-05    2.672957    4.496894   5.744716   0.621527  101.266846  ...
# 1990-01-08    2.679774    4.454997   5.722102   0.630735  100.638641  ...
# ...                ...         ...        ...        ...         ...  ...
# 2023-08-31  253.342285  221.940002  78.400002  74.570000   58.520000  ...
# 2023-09-01  254.476608  220.020004  77.519997  74.769997   59.240002  ...
# 2023-09-05  251.591049  219.460007  76.000000  74.199997   58.599998  ...
# 2023-09-06  249.800003  222.199997  76.379997  74.230003   59.189999  ...
# 2023-09-07  250.119995  221.009995  77.339996  74.650002   59.650002  ...
#
#                     WM        WMB         WMT        WRB         WST  \
# Date
# 1990-01-02    0.863414   1.503941    3.640321   1.006519    2.758530
# 1990-01-03    0.863414   1.537046    3.640321   1.021632    2.740262
# 1990-01-04    0.863414   1.489751    3.621010   1.012564    2.776799
# 1990-01-05    0.935365   1.494481    3.582385   1.012564    2.813335
# 1990-01-08    0.935365   1.513399    3.630667   1.009541    2.813335
# ...                ...        ...         ...        ...         ...
# 2023-08-31  156.076355  34.077545  162.610001  61.860001  406.899994
# 2023-09-01  156.305328  34.235447  161.570007  62.430000  407.690002
# 2023-09-05  156.325241  33.988724  160.270004  61.750000  403.670013
# 2023-09-06  155.270004  33.396587  161.470001  61.529999  404.850006
# 2023-09-07  156.899994  33.741997  163.470001  61.779999  403.859985
#
#                    WY        XEL         XOM       XRAY       ZION
# Date
# 1990-01-02   3.328015   4.213065    4.034966   0.855866   1.818956
# 1990-01-03   3.254712   4.200062    3.994619   0.855866   1.851438
# 1990-01-04   3.225389   4.096036    3.954268   0.821631   1.851438
# 1990-01-05   3.210728   4.057025    3.934095   0.872984   1.851438
# 1990-01-08   3.210728   4.018018    3.994619   0.838749   1.851438
# ...               ...        ...         ...        ...        ...
# 2023-08-31  32.750000  57.130001  111.190002  37.090000  35.500000
# 2023-09-01  32.750000  56.509998  113.519997  37.480000  36.439999
# 2023-09-05  31.920000  55.590000  113.529999  36.689999  36.130001
# 2023-09-06  32.389999  56.340000  114.510002  36.700001  34.820000
# 2023-09-07  32.450001  56.599998  113.949997  36.160000  33.860001
#
# [8486 rows x 252 columns]

# %%
log_returns = np.log(stock_prices_no_nulls).diff()[1:]
log_returns.head(3)
# Out:
#                 AAPL       ABT      ADBE       ADI       ADM       ADP  \
# Date
# 1990-01-03  0.006689  0.003603  0.048202 -0.053346  0.000000 -0.005025
# 1990-01-04  0.003331 -0.001799  0.045985 -0.013793 -0.005449 -0.005051
# 1990-01-05  0.003317 -0.010871  0.022223  0.000000 -0.044700 -0.007623
#
#                 ADSK       AEP       AFL       AIG  ...        WM       WMB  \
# Date                                                ...
# 1990-01-03  0.024541 -0.003781 -0.021506 -0.001185  ...  0.000000  0.021773
# 1990-01-04 -0.024541 -0.015268 -0.021979 -0.014338  ...  0.000000 -0.031254
# 1990-01-05  0.000000 -0.023348  0.000000 -0.030546  ...  0.080043  0.003170
#
#                  WMT       WRB       WST        WY       XEL       XOM  \
# Date
# 1990-01-03  0.000000  0.014903 -0.006644 -0.022272 -0.003091 -0.010050
# 1990-01-04 -0.005319 -0.008915  0.013245 -0.009050 -0.025080 -0.010153
# 1990-01-05 -0.010724  0.000000  0.013072 -0.004556 -0.009570 -0.005115
#
#                 XRAY    ZION
# Date
# 1990-01-03  0.000000  0.0177
# 1990-01-04 -0.040822  0.0000
# 1990-01-05  0.060625  0.0000
#
# [3 rows x 252 columns]

# %%
econ_df_interpolated_no_nulls_reindexed = econ_df_interpolated_no_nulls.reindex(log_returns.index)

# %%
econ_df_interpolated_no_nulls_reindexed.isnull().sum().sum()
# Out:
# 0

# %%
log_returns.isnull().sum().sum()
# Out:
# 0

# %%
log_returns.to_csv('data/cleaned/log_returns_daily.csv')

# %%
for i1, i2 in zip(log_returns.index, econ_df_interpolated_no_nulls_reindexed.index):
    assert i1 == i2

# %%
econ_df_interpolated_no_nulls_reindexed.to_csv('data/cleaned/econ_data_daily.csv')
